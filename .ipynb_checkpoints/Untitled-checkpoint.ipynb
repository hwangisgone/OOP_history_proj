# %%
# %load_ext line_profiler

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
URL = "https://vi.wikipedia.org/w/api.php"
PARAMS = {
    "action": "query",
    "cmlimit": "100",
    "list": "categorymembers",
    "format": "json"
}

def getAllPages(SET_OF_CATS):
    data = {}
    
    i = 0
    for cat in SET_OF_CATS:
          # GET ALL PAGES
        DATA = S.get(url=URL, params={**PARAMS, "cmtitle": cat, "cmtype": "page"}).json()
        PAGES = DATA['query']['categorymembers']
        for page in PAGES:
            data[i] = {"page": page['title'], "cat": cat}
            i += 1
            print(f'Progress: {i}', end='\r')
            
    return pd.DataFrame.from_dict(data, orient='index')


def recurseCat(S, catset, title, level=0, maxlevel=5):
        # RECURSIVE
    R = S.get(url=URL, params={**PARAMS, "cmtitle": title, "cmtype": "subcat"})
    DATA = R.json()
    # print(DATA)
    PAGES = DATA['query']['categorymembers']

    index = 1
    for page in PAGES:
        print("- "*level,index, page['title'])
        catset.add(page['title'])
        
        if (level < maxlevel):
            recurseCat(S, catset, page['title'], level+1, maxlevel)
        else:
            print("Max level reached")
        index += 1

# %%
toptitle = "Thể_loại:Kiến_trúc_cổ_Việt_Nam"
S = requests.Session()
new_set = set()

recurseCat(S, new_set, toptitle,maxlevel=4)
# Out:
#  1 Thể loại:Tháp Chăm
# -  1 Thể loại:Đền thờ Ấn Độ giáo tại Việt Nam
# -  2 Thể loại:Đền thờ vua chúa Chăm Pa
#  2 Thể loại:Chùa Việt Nam
# -  1 Thể loại:Chùa Việt Nam theo tỉnh thành
# - -  1 Thể loại:Chùa tại An Giang
# - -  2 Thể loại:Chùa tại Bạc Liêu
# - -  3 Thể loại:Chùa tại Bà Rịa – Vũng Tàu
# - -  4 Thể loại:Chùa tại Bắc Giang
# - -  5 Thể loại:Chùa tại Bắc Ninh
# - -  6 Thể loại:Chùa tại Bến Tre
# - -  7 Thể loại:Chùa tại Bình Định
# - -  8 Thể loại:Chùa tại Bình Dương
# - -  9 Thể loại:Chùa tại Bình Phước
# - -  10 Thể loại:Chùa tại Bình Thuận
# - -  11 Thể loại:Chùa tại Cần Thơ
# - -  12 Thể loại:Chùa tại Cà Mau
# - -  13 Thể loại:Chùa tại Đà Nẵng
# - -  14 Thể loại:Chùa tại Đắk Lắk
# - -  15 Thể loại:Chùa tại Đắk Nông
# - -  16 Thể loại:Chùa tại Đồng Tháp
# - -  17 Thể loại:Chùa tại Đồng Nai
# - -  18 Thể loại:Chùa tại Gia Lai
# - -  19 Thể loại:Chùa tại Hà Nam
# - -  20 Thể loại:Chùa tại Hà Nội
# - -  21 Thể loại:Chùa tại Hà Tĩnh
# - -  22 Thể loại:Chùa tại Hải Dương
# - -  23 Thể loại:Chùa tại Hải Phòng
# - -  24 Thể loại:Chùa tại Hòa Bình
# - -  25 Thể loại:Chùa tại Thành phố Hồ Chí Minh
# - -  26 Thể loại:Chùa tại Hưng Yên
# - -  27 Thể loại:Chùa tại Khánh Hòa
# - -  28 Thể loại:Chùa tại Kiên Giang
# - -  29 Thể loại:Chùa tại Kon Tum
# - -  30 Thể loại:Chùa tại Long An
# - -  31 Thể loại:Chùa tại Lạng Sơn
# - -  32 Thể loại:Chùa tại Lâm Đồng
# - -  33 Thể loại:Chùa tại Nam Định
# - -  34 Thể loại:Chùa tại Nghệ An
# - -  35 Thể loại:Chùa tại Ninh Bình
# - -  36 Thể loại:Chùa tại Phú Yên
# - -  37 Thể loại:Chùa tại Quảng Bình
# - -  38 Thể loại:Chùa tại Quảng Nam
# - -  39 Thể loại:Chùa tại Quảng Ngãi
# - -  40 Thể loại:Chùa tại Quảng Ninh
# - -  41 Thể loại:Chùa tại Quảng Trị
# - -  42 Thể loại:Chùa tại Sóc Trăng
# - -  43 Thể loại:Chùa tại Tây Ninh
# - -  44 Thể loại:Chùa tại Thái Bình
# - -  45 Thể loại:Chùa tại Thái Nguyên
# - -  46 Thể loại:Chùa tại Thanh Hóa
# - -  47 Thể loại:Chùa tại Thừa Thiên Huế
# - -  48 Thể loại:Chùa tại Tiền Giang
# - -  49 Thể loại:Chùa tại Trà Vinh
# - -  50 Thể loại:Chùa tại Vĩnh Long
# - -  51 Thể loại:Chùa tại Vĩnh Phúc
# -  2 Thể loại:Chùa Việt Nam tại hải ngoại
#  3 Thể loại:Cung điện tại Việt Nam
# -  1 Thể loại:Kinh thành Huế
# - -  1 Thể loại:Hệ thống thủy đạo Kinh thành Huế
# - -  2 Thể loại:Quốc sử quán
# - - -  1 Thể loại:Quốc sử quán (triều Nguyễn)
# - - - -  1 Thể loại:Tổng tài Quốc sử quán triều Nguyễn
# Max level reached
#  4 Thể loại:Di tích Việt Nam
# -  1 Thể loại:Di tích quốc gia đặc biệt
# -  2 Thể loại:Di tích Việt Nam theo tỉnh thành
# - -  1 Thể loại:Di tích tại An Giang
# - - -  1 Thể loại:Đình tại An Giang
# - -  2 Thể loại:Di tích tại Bà Rịa – Vũng Tàu
# - - -  1 Thể loại:Chùa tại Bà Rịa – Vũng Tàu
# - -  3 Thể loại:Di tích tại Bạc Liêu
# - - -  1 Thể loại:Chùa tại Bạc Liêu
# - -  4 Thể loại:Di tích tại Bắc Giang
# - - -  1 Thể loại:Chùa tại Bắc Giang
# - - -  2 Thể loại:Đình tại Bắc Giang
# - -  5 Thể loại:Di tích tại Bắc Kạn
# - -  6 Thể loại:Di tích tại Bắc Ninh
# - - -  1 Thể loại:Chùa tại Bắc Ninh
# - - -  2 Thể loại:Đình tại Bắc Ninh
# - -  7 Thể loại:Di tích tại Bến Tre
# - - -  1 Thể loại:Đình tại Bến Tre
# - -  8 Thể loại:Di tích tại Bình Dương
# - - -  1 Thể loại:Đình tại Bình Dương
# - -  9 Thể loại:Di tích tại Bình Định
# - - -  1 Thể loại:Chùa tại Bình Định
# - -  10 Thể loại:Di tích tại Bình Phước
# - -  11 Thể loại:Di tích tại Bình Thuận
# - -  12 Thể loại:Di tích tại Cà Mau
# - - -  1 Thể loại:Đình tại Cà Mau
# - -  13 Thể loại:Di tích tại Cao Bằng
# - -  14 Thể loại:Di tích tại Cần Thơ
# - - -  1 Thể loại:Đình tại Cần Thơ
# - -  15 Thể loại:Di tích tại Đà Nẵng
# - -  16 Thể loại:Di tích tại Điện Biên
# - -  17 Thể loại:Di tích tại Đồng Nai
# - - -  1 Thể loại:Chùa tại Đồng Nai
# - - -  2 Thể loại:Đình tại Đồng Nai
# - -  18 Thể loại:Di tích tại Đồng Tháp
# - - -  1 Thể loại:Đình tại Đồng Tháp
# - -  19 Thể loại:Di tích tại Đắk Lắk
# - - -  1 Thể loại:Chùa tại Đắk Lắk
# - - -  2 Thể loại:Đình tại Đắk Lắk
# - -  20 Thể loại:Di tích tại Đắk Nông
# - -  21 Thể loại:Di tích tại Gia Lai
# - -  22 Thể loại:Di tích tại Hà Nam
# - - -  1 Thể loại:Đình tại Hà Nam
# - -  23 Thể loại:Di tích tại Hà Nội
# - - -  1 Thể loại:Chùa tại Hà Nội
# - - -  2 Thể loại:Di tích Cố đô Thăng Long
# - - - -  1 Thể loại:Hoàng thành Thăng Long
# Max level reached
# - - - -  2 Thể loại:Thăng Long tứ quán
# Max level reached
# - - - -  3 Thể loại:Thăng Long tứ trấn
# Max level reached
# - - -  3 Thể loại:Đạo quán tại Hà Nội
# - - -  4 Thể loại:Đền tại Hà Nội
# - - - -  1 Thể loại:Thăng Long tứ trấn
# Max level reached
# - - -  5 Thể loại:Văn Miếu - Quốc Tử Giám
# - -  24 Thể loại:Di tích tại Hải Dương
# - -  25 Thể loại:Di tích tại Hậu Giang
# - -  26 Thể loại:Di tích tại Hưng Yên
# - -  27 Thể loại:Di tích tại Hà Giang
# - -  28 Thể loại:Di tích tại Hà Tĩnh
# - - -  1 Thể loại:Chùa tại Hà Tĩnh
# - - -  2 Thể loại:Đình tại Hà Tĩnh
# - -  29 Thể loại:Di tích tại Hải Phòng
# - - -  1 Thể loại:Chùa tại Hải Phòng
# - -  30 Thể loại:Di tích tại Thành phố Hồ Chí Minh
# - -  31 Thể loại:Di tích tại Hòa Bình
# - -  32 Thể loại:Di tích tại Khánh Hòa
# - - -  1 Thể loại:Đình tại Khánh Hòa
# - -  33 Thể loại:Di tích tại Kiên Giang
# - - -  1 Thể loại:Đình tại Kiên Giang
# - -  34 Thể loại:Di tích tại Kon Tum
# - -  35 Thể loại:Di tích tại Lạng Sơn
# - -  36 Thể loại:Di tích tại Long An
# - -  37 Thể loại:Di tích tại Lai Châu
# - -  38 Thể loại:Di tích tại Lào Cai
# - -  39 Thể loại:Di tích tại Lâm Đồng
# - -  40 Thể loại:Di tích tại Ninh Thuận
# - -  41 Thể loại:Di tích tại Nam Định
# - - -  1 Thể loại:Chùa tại Nam Định
# - -  42 Thể loại:Di tích tại Nghệ An
# - - -  1 Thể loại:Đình tại Nghệ An
# - -  43 Thể loại:Di tích tại Ninh Bình
# - - -  1 Thể loại:Chùa tại Ninh Bình
# - - -  2 Thể loại:Di tích Cố đô Hoa Lư
# - - -  3 Thể loại:Quần thể danh thắng Tràng An
# - -  44 Thể loại:Di tích tại Phú Thọ
# - -  45 Thể loại:Di tích tại Phú Yên
# - -  46 Thể loại:Di tích tại Quảng Nam
# - -  47 Thể loại:Di tích tại Quảng Bình
# - -  48 Thể loại:Di tích tại Quảng Ngãi
# - -  49 Thể loại:Di tích tại Quảng Ninh
# - - -  1 Thể loại:Chùa tại Quảng Ninh
# - - -  2 Thể loại:Đình tại Quảng Ninh
# - -  50 Thể loại:Di tích tại Quảng Trị
# - - -  1 Thể loại:Cụm Di tích Đôi bờ Hiền Lương
# - -  51 Thể loại:Di tích tại Sơn La
# - -  52 Thể loại:Di tích tại Sóc Trăng
# - -  53 Thể loại:Di tích tại Thừa Thiên Huế
# - - -  1 Thể loại:Di tích Cố đô Huế
# - - - -  1 Thể loại:Di tích ngoài Kinh Thành Huế
# Max level reached
# - - - -  2 Thể loại:Đàn tế cổ ở Huế
# Max level reached
# - - - -  3 Thể loại:Hệ thống thủy đạo Kinh thành Huế
# Max level reached
# - - - -  4 Thể loại:Hoàng thành Huế
# Max level reached
# - - - -  5 Thể loại:Kinh thành Huế
# Max level reached
# - - - -  6 Thể loại:Lăng tẩm Huế
# Max level reached
# - - - -  7 Thể loại:Tử Cấm thành (Huế)
# Max level reached
# - -  54 Thể loại:Di tích tại Tiền Giang
# - - -  1 Thể loại:Đình tại Tiền Giang
# - -  55 Thể loại:Di tích tại Trà Vinh
# - -  56 Thể loại:Di tích tại Tây Ninh
# - -  57 Thể loại:Di tích tại Thái Bình
# - -  58 Thể loại:Di tích tại Thái Nguyên
# - -  59 Thể loại:Di tích tại Thanh Hóa
# - - -  1 Thể loại:Đình tại Thanh Hóa
# - -  60 Thể loại:Di tích tại Tuyên Quang
# - -  61 Thể loại:Di tích tại Vĩnh Long
# - - -  1 Thể loại:Đình tại Vĩnh Long
# - -  62 Thể loại:Di tích tại Vĩnh Phúc
# - -  63 Thể loại:Di tích tại Yên Bái
# -  3 Thể loại:Công trình lưu niệm danh nhân trong lịch sử Việt Nam
# -  4 Thể loại:Di sản Quân chủ Việt Nam
# - -  1 Thể loại:Cố đô Việt Nam
# - - -  1 Thể loại:Di tích Cố đô Hoa Lư
# - - -  2 Thể loại:Huế
# - - - -  1 Thể loại:Công trình xây dựng Huế
# Max level reached
# - - - -  2 Thể loại:Di tích Cố đô Huế
# Max level reached
# - - - -  3 Thể loại:Du lịch Huế
# Max level reached
# - - - -  4 Thể loại:Địa lý Huế
# Max level reached
# - - - -  5 Thể loại:Lịch sử Huế
# Max level reached
# - - - -  6 Thể loại:Người Huế
# Max level reached
# - - - -  7 Thể loại:Tôn giáo ở Huế
# Max level reached
# - - - -  8 Thể loại:Văn hóa Huế
# Max level reached
# - - - -  9 Thể loại:Xã, phường thuộc thành phố Huế
# Max level reached
# - -  2 Thể loại:Di tích Cố đô Huế
# - - -  1 Thể loại:Di tích ngoài Kinh Thành Huế
# - - -  2 Thể loại:Đàn tế cổ ở Huế
# - - -  3 Thể loại:Hệ thống thủy đạo Kinh thành Huế
# - - -  4 Thể loại:Hoàng thành Huế
# - - -  5 Thể loại:Kinh thành Huế
# - - - -  1 Thể loại:Hệ thống thủy đạo Kinh thành Huế
# Max level reached
# - - - -  2 Thể loại:Quốc sử quán
# Max level reached
# - - -  6 Thể loại:Lăng tẩm Huế
# - - - -  1 Thể loại:Lăng tẩm các vua, chúa Nguyễn
# Max level reached
# - - -  7 Thể loại:Tử Cấm thành (Huế)
# - -  3 Thể loại:Di tích Cố đô Thăng Long
# - - -  1 Thể loại:Hoàng thành Thăng Long
# - - -  2 Thể loại:Thăng Long tứ quán
# - - -  3 Thể loại:Thăng Long tứ trấn
# - -  4 Thể loại:Di sản triều đại nhà Nguyễn
# - - -  1 Thể loại:Quốc sử quán (triều Nguyễn)
# - - - -  1 Thể loại:Tổng tài Quốc sử quán triều Nguyễn
# Max level reached
# - - -  2 Thể loại:Thành Việt Nam thời Nguyễn
# - - -  3 Thể loại:Văn hóa Việt Nam thời Nguyễn
# - - - -  1 Thể loại:Di tích Cố đô Huế
# Max level reached
# - - - -  2 Thể loại:Nghệ thuật Việt Nam thời Nguyễn
# Max level reached
# - - - -  3 Thể loại:Nhạc cung đình Huế
# Max level reached
# - - - -  4 Thể loại:Thần kinh nhị thập cảnh
# Max level reached
# - - - -  5 Thể loại:Trò chơi cung đình Huế dưới Triều Nguyễn
# Max level reached
# -  5 Thể loại:Di tích lịch sử Việt Nam
# - -  1 Thể loại:Di tích lịch sử Việt Nam tại Trung Quốc
# - -  2 Thể loại:Phố cổ tại Việt Nam
# - - -  1 Thể loại:Phố cổ Hội An
# - - -  2 Thể loại:Khu phố cổ Hà Nội
# -  6 Thể loại:Di tích lịch sử Việt Nam tại Trung Quốc
# -  7 Thể loại:Di tích nhà Lý
# -  8 Thể loại:Điểm tham quan ở Việt Nam
# - -  1 Thể loại:Bãi biển Việt Nam
# - - -  1 Thể loại:Bãi biển Quy Nhơn
# - - -  2 Thể loại:Bãi biển Đà Nẵng
# - -  2 Thể loại:Bảo tàng tại Việt Nam
# - - -  1 Thể loại:Bảo tàng Mỹ thuật Việt Nam
# - - - -  1 Thể loại:Hiện vật Bảo tàng Mỹ thuật Việt Nam
# Max level reached
# - - -  2 Thể loại:Bảo tàng về Chiến tranh Việt Nam
# - - - -  1 Thể loại:Bảo tàng Lịch sử Quân sự Việt Nam
# Max level reached
# - - -  3 Thể loại:Bảo tàng tại Đà Nẵng
# - - -  4 Thể loại:Bảo tàng tại Đắk Lắk
# - - -  5 Thể loại:Bảo tàng tại Hà Nội
# - - - -  1 Thể loại:Bảo tàng Lịch sử Quân sự Việt Nam
# Max level reached
# - - - -  2 Thể loại:Viện bảo tàng lịch sử Việt Nam
# Max level reached
# - - -  6 Thể loại:Bảo tàng Quân đội nhân dân Việt Nam
# - - - -  1 Thể loại:Bảo tàng Lịch sử Quân sự Việt Nam
# Max level reached
# - - -  7 Thể loại:Bảo tàng tại Thành phố Hồ Chí Minh
# - -  3 Thể loại:Công trình tôn giáo tại Việt Nam
# - - -  1 Thể loại:Chùa Việt Nam
# - - - -  1 Thể loại:Chùa Việt Nam theo tỉnh thành
# Max level reached
# - - - -  2 Thể loại:Chùa Việt Nam tại hải ngoại
# Max level reached
# - - -  2 Thể loại:Đền thờ Ấn Độ giáo tại Việt Nam
# - - -  3 Thể loại:Đàn Xã Tắc
# - - -  4 Thể loại:Đền tại Việt Nam
# - - - -  1 Thể loại:Đình Việt Nam
# Max level reached
# - - - -  2 Thể loại:Miếu Việt Nam
# Max level reached
# - - - -  3 Thể loại:Tháp Chăm
# Max level reached
# - - - -  4 Thể loại:Đền tại Hà Nội
# Max level reached
# - - - -  5 Thể loại:Đền tại Thành phố Hồ Chí Minh
# Max level reached
# - - - -  6 Thể loại:Văn miếu tại Việt Nam
# Max level reached
# - - -  5 Thể loại:Công trình tôn giáo tại Hà Nội
# - - - -  1 Thể loại:Chùa tại Hà Nội
# Max level reached
# - - - -  2 Thể loại:Đạo quán tại Hà Nội
# Max level reached
# - - - -  3 Thể loại:Đền tại Hà Nội
# Max level reached
# - - - -  4 Thể loại:Đình tại Hà Nội
# Max level reached
# - - - -  5 Thể loại:Nhà thờ tại Hà Nội
# Max level reached
# - - -  6 Thể loại:Công trình tôn giáo tại Thành phố Hồ Chí Minh
# - - - -  1 Thể loại:Chùa tại Thành phố Hồ Chí Minh
# Max level reached
# - - - -  2 Thể loại:Công trình tôn giáo do người Hoa xây dựng tại Sài Gòn
# Max level reached
# - - - -  3 Thể loại:Đền tại Thành phố Hồ Chí Minh
# Max level reached
# - - - -  4 Thể loại:Đình tại Thành phố Hồ Chí Minh
# Max level reached
# - - - -  5 Thể loại:Miếu tại Thành phố Hồ Chí Minh
# Max level reached
# - - - -  6 Thể loại:Nhà thờ tại Thành phố Hồ Chí Minh
# Max level reached
# - - -  7 Thể loại:Nhà thờ tại Việt Nam
# - - - -  1 Thể loại:Nhà thờ Công giáo tại Việt Nam
# Max level reached
# - - - -  2 Thể loại:Nhà thờ Tin Lành tại Việt Nam
# Max level reached
# - - - -  3 Thể loại:Nhà thờ tại An Giang
# Max level reached
# - - - -  4 Thể loại:Nhà thờ tại Đắk Lắk
# Max level reached
# - - - -  5 Thể loại:Nhà thờ tại Hà Tĩnh
# Max level reached
# - - - -  6 Thể loại:Nhà thờ tại Hà Nội
# Max level reached
# - - - -  7 Thể loại:Nhà thờ tại Thành phố Hồ Chí Minh
# Max level reached
# - - - -  8 Thể loại:Nhà thờ tại Khánh Hòa
# Max level reached
# - - - -  9 Thể loại:Nhà thờ tại Kontum
# Max level reached
# - - - -  10 Thể loại:Nhà thờ tại Lào Cai
# Max level reached
# - - - -  11 Thể loại:Nhà thờ tại Lâm Đồng
# Max level reached
# - - - -  12 Thể loại:Nhà thờ tại Ninh Bình
# Max level reached
# - - - -  13 Thể loại:Nhà thờ tại Nam Định
# Max level reached
# - - - -  14 Thể loại:Nhà thờ tại Nghệ An
# Max level reached
# - - - -  15 Thể loại:Nhà thờ Việt Nam tại hải ngoại
# Max level reached
# - - - -  16 Thể loại:Nhà thờ tại Phú Yên
# Max level reached
# - - - -  17 Thể loại:Nhà thờ tại Quảng Bình
# Max level reached
# - - - -  18 Thể loại:Nhà thờ tại Quảng Ninh
# Max level reached
# - - - -  19 Thể loại:Nhà thờ tại Tây Ninh
# Max level reached
# - - - -  20 Thể loại:Nhà thờ tại Thừa Thiên Huế
# Max level reached
# - - - -  21 Thể loại:Vương cung thánh đường tại Việt Nam
# Max level reached
# - - -  8 Thể loại:Thánh thất Cao Đài
# - - -  9 Thể loại:Tu viện Việt Nam
# - -  4 Thể loại:Công viên Việt Nam
# - - -  1 Thể loại:Công viên vui chơi tại Việt Nam
# - - -  2 Thể loại:Công viên tại Hà Nội
# - - - -  1 Thể loại:Vườn hoa Hà Nội
# Max level reached
# - - -  3 Thể loại:Công viên tại Thành phố Hồ Chí Minh
# - - -  4 Thể loại:Vườn ở Việt Nam
# - - - -  1 Thể loại:Vườn thú tại Việt Nam
# Max level reached
# - - -  5 Thể loại:Vườn quốc gia Việt Nam
# - -  5 Thể loại:Di sản thế giới tại Việt Nam
# - - -  1 Thể loại:Di tích Cố đô Huế
# - - - -  1 Thể loại:Di tích ngoài Kinh Thành Huế
# Max level reached
# - - - -  2 Thể loại:Đàn tế cổ ở Huế
# Max level reached
# - - - -  3 Thể loại:Hệ thống thủy đạo Kinh thành Huế
# Max level reached
# - - - -  4 Thể loại:Hoàng thành Huế
# Max level reached
# - - - -  5 Thể loại:Kinh thành Huế
# Max level reached
# - - - -  6 Thể loại:Lăng tẩm Huế
# Max level reached
# - - - -  7 Thể loại:Tử Cấm thành (Huế)
# Max level reached
# - -  6 Thể loại:Di tích lịch sử Việt Nam
# - - -  1 Thể loại:Di tích lịch sử Việt Nam tại Trung Quốc
# - - -  2 Thể loại:Phố cổ tại Việt Nam
# - - - -  1 Thể loại:Phố cổ Hội An
# Max level reached
# - - - -  2 Thể loại:Khu phố cổ Hà Nội
# Max level reached
# - -  7 Thể loại:Địa điểm giải trí ở Việt Nam
# - - -  1 Thể loại:Công viên vui chơi tại Việt Nam
# - - -  2 Thể loại:Sân vận động tại Việt Nam
# - - - -  1 Thể loại:Sân vận động Hà Nội
# Max level reached
# - - - -  2 Thể loại:Sân vận động đa năng Việt Nam
# Max level reached
# - - - -  3 Thể loại:Địa điểm bóng đá Việt Nam
# Max level reached
# - - - -  4 Thể loại:Địa điểm điền kinh Việt Nam
# Max level reached
# - - - -  5 Thể loại:Sân golf Việt Nam
# Max level reached
# - - - -  6 Thể loại:Nhà thi đấu Việt Nam
# Max level reached
# - - - -  7 Thể loại:Địa điểm thể thao tại Thành phố Hồ Chí Minh
# Max level reached
# - - -  3 Thể loại:Vườn thú tại Việt Nam
# - -  8 Thể loại:Hang động Việt Nam
# - - -  1 Thể loại:Hang động tại Ninh Bình
# - - -  2 Thể loại:Hang động tại Quảng Bình
# - -  9 Thể loại:Hồ Việt Nam
# - - -  1 Thể loại:Hồ tại Việt Nam theo tỉnh thành
# - - - -  1 Thể loại:Hồ tại An Giang
# Max level reached
# - - - -  2 Thể loại:Hồ tại Bắc Giang
# Max level reached
# - - - -  3 Thể loại:Hồ tại Bắc Kạn
# Max level reached
# - - - -  4 Thể loại:Hồ tại Bến Tre
# Max level reached
# - - - -  5 Thể loại:Hồ tại Bình Dương
# Max level reached
# - - - -  6 Thể loại:Hồ tại Bình Định
# Max level reached
# - - - -  7 Thể loại:Hồ tại Bình Phước
# Max level reached
# - - - -  8 Thể loại:Hồ tại Bình Thuận
# Max level reached
# - - - -  9 Thể loại:Hồ tại Cao Bằng
# Max level reached
# - - - -  10 Thể loại:Hồ tại Đắk Lắk
# Max level reached
# - - - -  11 Thể loại:Hồ tại Đắk Nông
# Max level reached
# - - - -  12 Thể loại:Hồ tại Điện Biên
# Max level reached
# - - - -  13 Thể loại:Hồ tại Đồng Nai
# Max level reached
# - - - -  14 Thể loại:Hồ tại Gia Lai
# Max level reached
# - - - -  15 Thể loại:Hồ tại Hà Tĩnh
# Max level reached
# - - - -  16 Thể loại:Hồ tại Hà Giang
# Max level reached
# - - - -  17 Thể loại:Hồ tại Hà Nội
# Max level reached
# - - - -  18 Thể loại:Hồ tại Hòa Bình
# Max level reached
# - - - -  19 Thể loại:Hồ tại Kon Tum
# Max level reached
# - - - -  20 Thể loại:Hồ tại Lai Châu
# Max level reached
# - - - -  21 Thể loại:Hồ tại Lào Cai
# Max level reached
# - - - -  22 Thể loại:Hồ tại Lâm Đồng
# Max level reached
# - - - -  23 Thể loại:Hồ tại Nghệ An
# Max level reached
# - - - -  24 Thể loại:Hồ tại Ninh Bình
# Max level reached
# - - - -  25 Thể loại:Hồ tại Phú Yên
# Max level reached
# - - - -  26 Thể loại:Hồ tại Quảng Nam
# Max level reached
# - - - -  27 Thể loại:Hồ tại Quảng Bình
# Max level reached
# - - - -  28 Thể loại:Hồ tại Quảng Ninh
# Max level reached
# - - - -  29 Thể loại:Hồ tại Sơn La
# Max level reached
# - - - -  30 Thể loại:Hồ tại Thái Nguyên
# Max level reached
# - - - -  31 Thể loại:Hồ tại Tây Ninh
# Max level reached
# - - - -  32 Thể loại:Hồ tại Thanh Hóa
# Max level reached
# - - - -  33 Thể loại:Hồ tại Thừa Thiên Huế
# Max level reached
# - - - -  34 Thể loại:Hồ tại Tuyên Quang
# Max level reached
# - - - -  35 Thể loại:Hồ tại Vĩnh Phúc
# Max level reached
# - - - -  36 Thể loại:Hồ tại Yên Bái
# Max level reached
# - -  10 Thể loại:Danh lam thắng cảnh tại Huế
# - - -  1 Thể loại:Sông Hương
# - - - -  1 Thể loại:Cầu qua sông Hương
# Max level reached
# - - -  2 Thể loại:Thần kinh nhị thập cảnh
# - -  11 Thể loại:Khu bảo tồn Việt Nam
# - - -  1 Thể loại:Công viên Việt Nam
# - - - -  1 Thể loại:Công viên vui chơi tại Việt Nam
# Max level reached
# - - - -  2 Thể loại:Công viên tại Hà Nội
# Max level reached
# - - - -  3 Thể loại:Công viên tại Thành phố Hồ Chí Minh
# Max level reached
# - - - -  4 Thể loại:Vườn ở Việt Nam
# Max level reached
# - - - -  5 Thể loại:Vườn quốc gia Việt Nam
# Max level reached
# - - -  2 Thể loại:Khu bảo tồn thiên nhiên Việt Nam
# - - -  3 Thể loại:Khu Ramsar Việt Nam
# - - -  4 Thể loại:Khu dự trữ sinh quyển Việt Nam
# - - -  5 Thể loại:Vườn quốc gia Việt Nam
# - -  12 Thể loại:Quảng trường Việt Nam
# - - -  1 Thể loại:Quảng trường tại Hà Nội
# - - -  2 Thể loại:Quảng trường tại Thành phố Hồ Chí Minh
# - -  13 Thể loại:Thác nước Việt Nam
# - -  14 Thể loại:Vườn ở Việt Nam
# - - -  1 Thể loại:Vườn thú tại Việt Nam
# - -  15 Thể loại:Vườn thú tại Việt Nam
# -  9 Thể loại:Di tích khảo cổ Việt Nam
# -  10 Thể loại:Di tích kiến trúc nghệ thuật Việt Nam
# - -  1 Thể loại:Phố cổ tại Việt Nam
# - - -  1 Thể loại:Phố cổ Hội An
# - - -  2 Thể loại:Khu phố cổ Hà Nội
# -  11 Thể loại:Phố cổ tại Việt Nam
# - -  1 Thể loại:Phố cổ Hội An
# - -  2 Thể loại:Khu phố cổ Hà Nội
# -  12 Thể loại:Di tích quốc gia Việt Nam
# - -  1 Thể loại:Di tích quốc gia đặc biệt
# - -  2 Thể loại:Di sản thế giới tại Việt Nam
# - - -  1 Thể loại:Di tích Cố đô Huế
# - - - -  1 Thể loại:Di tích ngoài Kinh Thành Huế
# Max level reached
# - - - -  2 Thể loại:Đàn tế cổ ở Huế
# Max level reached
# - - - -  3 Thể loại:Hệ thống thủy đạo Kinh thành Huế
# Max level reached
# - - - -  4 Thể loại:Hoàng thành Huế
# Max level reached
# - - - -  5 Thể loại:Kinh thành Huế
# Max level reached
# - - - -  6 Thể loại:Lăng tẩm Huế
# Max level reached
# - - - -  7 Thể loại:Tử Cấm thành (Huế)
# Max level reached
# -  13 Thể loại:Thương cảng cổ Việt Nam
#  5 Thể loại:Đền tại Việt Nam
# -  1 Thể loại:Đình Việt Nam
# - -  1 Thể loại:Đình tại An Giang
# - -  2 Thể loại:Đình tại Bắc Giang
# - -  3 Thể loại:Đình tại Bắc Ninh
# - -  4 Thể loại:Đình tại Bến Tre
# - -  5 Thể loại:Đình tại Bình Dương
# - -  6 Thể loại:Đình tại Cà Mau
# - -  7 Thể loại:Đình tại Cần Thơ
# - -  8 Thể loại:Đình tại Đắk Lắk
# - -  9 Thể loại:Đình tại Đồng Nai
# - -  10 Thể loại:Đình tại Đồng Tháp
# - -  11 Thể loại:Đình tại Hà Nam
# - -  12 Thể loại:Đình tại Hà Nội
# - -  13 Thể loại:Đình tại Hà Tĩnh
# - -  14 Thể loại:Đình tại Khánh Hòa
# - -  15 Thể loại:Đình tại Kiên Giang
# - -  16 Thể loại:Đình tại Nghệ An
# - -  17 Thể loại:Đình tại Quảng Ninh
# - -  18 Thể loại:Đình tại Thanh Hóa
# - -  19 Thể loại:Đình tại Tiền Giang
# - -  20 Thể loại:Đình tại Thành phố Hồ Chí Minh
# - -  21 Thể loại:Đình tại Vĩnh Long
# -  2 Thể loại:Miếu Việt Nam
# - -  1 Thể loại:Miếu tại Thành phố Hồ Chí Minh
# -  3 Thể loại:Tháp Chăm
# - -  1 Thể loại:Đền thờ Ấn Độ giáo tại Việt Nam
# - -  2 Thể loại:Đền thờ vua chúa Chăm Pa
# -  4 Thể loại:Đền tại Hà Nội
# - -  1 Thể loại:Thăng Long tứ trấn
# -  5 Thể loại:Đền tại Thành phố Hồ Chí Minh
# -  6 Thể loại:Văn miếu tại Việt Nam
#  6 Thể loại:Đình Việt Nam
# -  1 Thể loại:Đình tại An Giang
# -  2 Thể loại:Đình tại Bắc Giang
# -  3 Thể loại:Đình tại Bắc Ninh
# -  4 Thể loại:Đình tại Bến Tre
# -  5 Thể loại:Đình tại Bình Dương
# -  6 Thể loại:Đình tại Cà Mau
# -  7 Thể loại:Đình tại Cần Thơ
# -  8 Thể loại:Đình tại Đắk Lắk
# -  9 Thể loại:Đình tại Đồng Nai
# -  10 Thể loại:Đình tại Đồng Tháp
# -  11 Thể loại:Đình tại Hà Nam
# -  12 Thể loại:Đình tại Hà Nội
# -  13 Thể loại:Đình tại Hà Tĩnh
# -  14 Thể loại:Đình tại Khánh Hòa
# -  15 Thể loại:Đình tại Kiên Giang
# -  16 Thể loại:Đình tại Nghệ An
# -  17 Thể loại:Đình tại Quảng Ninh
# -  18 Thể loại:Đình tại Thanh Hóa
# -  19 Thể loại:Đình tại Tiền Giang
# -  20 Thể loại:Đình tại Thành phố Hồ Chí Minh
# -  21 Thể loại:Đình tại Vĩnh Long
#  7 Thể loại:Kiến trúc Việt Nam thời Mạc
# -  1 Thể loại:Thành nhà Mạc
#  8 Thể loại:Làng cổ Việt Nam
# -  1 Thể loại:Làng cổ An Giang
# -  2 Thể loại:Làng cổ Bắc Giang
# -  3 Thể loại:Làng cổ Bắc Ninh
# -  4 Thể loại:Làng cổ Cần Thơ
# -  5 Thể loại:Làng cổ Đà Nẵng
# -  6 Thể loại:Làng cổ Đồng Nai
# -  7 Thể loại:Làng cổ Hà Nội
# -  8 Thể loại:Làng cổ Hà Tĩnh
# -  9 Thể loại:Làng cổ Hưng Yên
# -  10 Thể loại:Làng cổ Hà Nam
# -  11 Thể loại:Làng cổ Nam Định
# -  12 Thể loại:Làng cổ Ninh Bình
# -  13 Thể loại:Làng cổ Quảng Ninh
# -  14 Thể loại:Làng cổ Quảng Trị
# -  15 Thể loại:Làng cổ Thanh Hóa
#  9 Thể loại:Lăng mộ Việt Nam
# -  1 Thể loại:Lăng tẩm Huế
# - -  1 Thể loại:Lăng tẩm các vua, chúa Nguyễn
#  10 Thể loại:Miếu Việt Nam
# -  1 Thể loại:Miếu tại Thành phố Hồ Chí Minh
#  11 Thể loại:Phố cổ tại Việt Nam
# -  1 Thể loại:Phố cổ Hội An
# -  2 Thể loại:Khu phố cổ Hà Nội
#  12 Thể loại:Thành cổ Việt Nam
# -  1 Thể loại:Thành Chăm Pa
# - -  1 Thể loại:Kinh đô Chăm Pa
# - - -  1 Thể loại:Indrapura
# - - - -  1 Thể loại:Lãnh tụ Indrapura
# Max level reached
# -  2 Thể loại:Thành Việt Nam thời Nguyễn

# %%
s = list(new_set)
df = pd.DataFrame(s)
df.columns = ['test']

substr = [
    'Di tích',
    'Chùa',
    'Đình',
    'Đền',
    'Miếu',
    'miếu',
    'Phố cổ',
    'Hoàng thành',
    'Lăng mộ',
    'Cung điện',
]
df = df[df.test.str.contains('|'.join(substr))].reset_index(drop=True)

# %%
all_pages = getAllPages(df.test)

allnodup = all_pages.drop_duplicates('page')
allnodup = allnodup.sort_values('page')
allnodup
# Out:
# Progress: 1473
#                           page                                     cat
# 580             An toàn khu II          Thể loại:Di tích tại Bắc Giang
# 589       An toàn khu Định Hóa        Thể loại:Di tích tại Thái Nguyên
# 553                   Ao Bà Om           Thể loại:Di tích tại Trà Vinh
# 226                 Bia Lê Lợi           Thể loại:Di tích tại Lai Châu
# 1284              Bia Lạc Giao            Thể loại:Di tích tại Đắk Lắk
# ...                        ...                                     ...
# 1230             Động Tiên Phi      Thể loại:Di tích quốc gia Việt Nam
# 227   Động Tiên Sơn (Lai Châu)           Thể loại:Di tích tại Lai Châu
# 1231              Động Từ Thức      Thể loại:Di tích quốc gia Việt Nam
# 1232               Động Xá Nhè      Thể loại:Di tích quốc gia Việt Nam
# 415             Đức Mẹ Bãi Dâu  Thể loại:Di tích tại Bà Rịa – Vũng Tàu
#
# [986 rows x 2 columns]

# %%
# Fetch the HTML content of the webpage
def infobox_dict_thing(url):
    response = requests.get(url)
    html = response.json()['parse']['text']

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html, "html.parser")

    # Find the infobox template and extract its contents
    infobox = soup.find("table", {"class": "infobox"})
    if not infobox:
        return {}
        
    rows = infobox.find_all("tr")

    # Convert the infobox contents into a Pandas DataFrame
    data = {}
    for row in rows:
        cells = row.find_all(["th", "td"])
        if len(cells) > 1:
            key = cells[0].get_text().strip()
            value = cells[1].get_text().strip()
            data[key] = value

    return data

# %%
def iterate_dict_infobox(url, list_of_loc, infoboxer):
    list_dict = []
    maxi = len(list_of_loc)
    i = 0
    for loc in list_of_loc:
        dict2 = {'page': loc, **infoboxer(url + loc)}
        list_dict.append(dict2)
        print(dict2)
        print(f'{i/maxi*100:.2f}%', end='\r')
        i += 1


    return list_dict

# %%
# url = 'https://vi.wikipedia.org/w/api.php?action=parse&prop=wikitext&format=json&page='
HTMLURL = 'https://vi.wikipedia.org/w/api.php?action=parse&prop=text&formatversion=2&format=json&page='
# %lprun -f iterate_dict_infobox iterate_dict_infobox(url, allnodup.page[0:20], infobox_dict_thing)

alldata = iterate_dict_infobox(url, allnodup.page, infobox_dict_thing)
# Out:
# {'page': 'Chùa Đọi Sơn'}
# {'page': 'Đền Lăng', 'Tên khác': 'Đền Ninh Thái', 'Địa chỉ': 'xã Liêm Cần, huyện Thanh Liêm, tỉnh Hà Nam,\xa0Việt Nam'}
# {'page': 'Đền Trần Thương', 'Địa chỉ': 'thôn Trần Thương, xã Trần Hưng Đạo, huyện Lý Nhân, Hà Nam,\xa0Việt Nam', 'Tọa độ': '20°34′34″B 106°06′13″Đ\ufeff / \ufeff20,5761573°B 106,1037476°Đ\ufeff / 20.5761573; 106.1037476', 'Lễ hội': '14-15 tháng Giêng âm lịch\n20 tháng 8 âm lịch', 'Phân loại': 'Di tích lịch sử – văn hóa', 'Ngày công nhận': '1989', 'Quyết định': '2367/QĐ-TTg[1]'}
# {'page': 'Kẽm Trống'}
# {'page': 'Miếu Thượng (Đặng Xá)', 'Địa chỉ': 'thôn Đặng Xá, xã Văn Xá, huyện Kim Bảng, tỉnh Hà Nam,\xa0Việt Nam', 'Thành lập': 'Thời Đinh'}
# {'page': 'Chùa Hoằng Phúc', 'Quốc gia': 'Việt Nam', 'Địa chỉ': 'thôn Thuận Trạch, xã Mỹ Thủy, huyện Lệ Thủy,tỉnh Quảng Bình', 'Tôn giáo': 'Phật giáo', 'Tông phái': 'Giáo hội Phật giáo Việt Nam', 'Khởi lập': 'Khu Chùa cổ 700 năm trướcKhu Chùa mới năm 2016\nChùa Hoằng Phúc tại Quảng BìnhChùa Hoằng Phúc tại Quảng Bình (Việt Nam)', 'Quản lý': 'Giáo hội Phật giáo Việt Nam', 'Trụ trì': 'TT. Thích Đức Thiện', 'Trang web': 'https://m.facebook.com/Ch%C3%B9a-Ho%E1%BA%B1ng-Ph%C3%BAc-1730688997152551/'}
# {'page': 'Chùa Sóc Lớn', 'Tên khác': 'Wat Phum Thum', 'Quốc gia': 'Việt Nam', 'Địa chỉ': 'Ấp Sóc Lớn, xã Lộc Khánh, huyện Lộc Ninh, tỉnh Bình Phước', 'Tôn giáo': 'Phật giáo', 'Tông phái': 'Phật giáo Nam tông Khmer', 'Tôn kính': 'Phật Thích Ca', 'Khởi lập': '1931  1937: Khánh thành', 'Người sáng lập': 'Tuôch Chap, Lâm Mứt, Lâm Mơm, Lâm Keo, Lâm Duôn và các Phật tử trong Phum Sóc', 'Phân loại': 'Di tích lịch sử – văn hoá', 'Ngày công nhận': '15 tháng 12 năm 2004\xa0(2004-12-15)'}
# {'page': 'Đình Bình Hòa', 'Địa chỉ': 'Bình Thạnh, Thành phố Hồ Chí Minh,\xa0Việt Nam', 'Thành lập': 'thế kỷ 19', 'Phân loại': 'Di tích kiến trúc nghệ thuật', 'Ngày công nhận': '7 tháng 1 năm 1993', 'Quyết định': '43VH/QĐ'}
# {'page': 'Đình Bình Trường'}
# {'page': 'Đình Chí Hòa'}
# {'page': 'Đình Minh Hương Gia Thạnh'}
# {'page': 'Hội quán Nghĩa Nhuận'}
# {'page': 'Đình Thái Hưng'}
# {'page': 'Đình Thông Tây Hội'}
# {'page': 'Chùa Đót Sơn'}
# {'page': 'Chùa Hang (Đồ Sơn)'}
# {'page': 'Chùa Phúc Lâm (Hải Phòng)'}
# {'page': 'Chùa Trà Phương'}
# {'page': 'Lăng Cha Cả'}
# {'page': 'Lăng đá Quận Vân'}
# {'page': 'Thái Hà Ấp'}
# {'page': 'Lăng Chủ tịch Hồ Chí Minh', 'Tên cũ': 'Lăng Hồ Chủ tịch', 'Dạng': 'Lăng mộ', 'Phong cách': 'Hiện đại', 'Địa điểm': 'Quảng trường Ba Đình', 'Quốc gia': 'Việt Nam', 'Thành phố': 'Hà Nội', 'Địa chỉ': '2 Hùng Vương, Điện Biên, Ba Đình, Hà Nội', 'Tọa độ': '21°02′12″B 105°50′05″Đ\ufeff / \ufeff21,036747°B 105,8347°Đ\ufeff / 21.036747; 105.8347', 'Khởi công': '2 tháng 9 năm 1973', 'Hoàn thành': '16 tháng 5 năm 1975', 'Khánh thành': '29 tháng 8 năm 1975', 'Trùng tu': 'Tháng 10, 11', 'Diện tích sàn': '21000 m²', 'Kích thước': 'Mỗi cạnh 30 m', 'Đường kính': '10 m', 'Kiến trúc sư': 'Garol Isakovich'}
# {'page': 'Lăng Dinh Hương'}
# {'page': 'Lăng Ông (Bà Chiểu)'}
# {'page': 'Lăng Họ Ngọ'}
# {'page': 'Lăng Ngô Quyền'}
# {'page': 'Lăng Nguyễn Đình Chiểu'}
# {'page': 'Lăng Nguyễn Hữu Hào', 'Quốc gia': 'Việt Nam', 'Thành phố': 'Đà Lạt', 'Địa chỉ': 'Ngã ba đường Hoàng Văn Thụ - Vạn Thành', 'Tọa độ': '11°56′34″B 108°24′55″Đ\ufeff / \ufeff11,942748°B 108,415409°Đ\ufeff / 11.942748; 108.415409', 'Chủ đầu tư': 'Nam Phương Hoàng hậu Nguyễn Hữu Thị Lan', 'Khởi công': '1939', 'Hoàn thành': '10 tháng 9 năm 1941'}
# {'page': 'Nhà mồ Tây Nguyên'}
# {'page': 'Lăng Hoàng gia'}
# {'page': 'Lăng Trương Định'}
# {'page': 'Lăng Tứ Kiệt', 'Dạng': 'Lăng mộ', 'Phong cách': 'Truyền thống', 'Hệ thống kết cấu': '1871: Bằng đất\n1954: Bằng xi măng', 'Quốc gia': 'Việt Nam', 'Địa chỉ': 'Đường 30–4, phường 1, thị xã Cai Lậy, tỉnh Tiền Giang', 'Tọa độ': '10°24′31,3″B 106°07′9,3″Đ\ufeff / \ufeff10,4°B 106,11667°Đ\ufeff / 10.40000; 106.11667', 'Khởi công': '1871', 'Trùng tu': '1967, 1997', 'Kiến trúc sư': 'Nhân dân Cai Lậy', 'Kỹ sư': 'Nhân dân Cai Lậy'}
# {'page': 'Đồi Chóp Chài'}
# {'page': 'Thánh địa Mỹ Sơn', 'Tọa độ': '15°46′B 108°07′Đ\ufeff / \ufeff15,767°B 108,117°Đ\ufeff / 15.767; 108.117', 'Quốc gia': 'Việt Nam', 'Tỉnh': 'Quảng Nam', 'Kiểu dáng kiến trúc': 'Chăm', 'Tên chính thức': 'Thánh địa Mỹ Sơn', 'Tiêu chuẩn': 'Văn hóa: (ii), (iii)', 'Tham khảo': '949', 'Công nhận': '1999 (Kỳ họp 23)', 'Diện tích': '142\xa0ha (0,55\xa0dặm\xa0vuông\xa0Anh)', 'Vùng đệm': '920\xa0ha (3,6\xa0dặm\xa0vuông\xa0Anh)'}
# {'page': 'Phật viện Đồng Dương', 'Vị trí Tháp Đồng Dương trên bản đồ Việt Nam\n\n\nTháp Đồng Dương': 'Vị trí Tháp Đồng Dương trên bản đồ Việt Nam', 'Phong cách': 'Đồng Dương', 'Xây dựng': 'Thế kỷ 9', 'Địa chỉ': 'làng Đồng Dương, huyện Thăng Bình', 'Vị trí': 'Quảng Nam,\xa0 Việt Nam', 'Tọa độ': '15°40′31″B 108°17′40″Đ\ufeff / \ufeff15,675327°B 108,294381°Đ\ufeff / 15.675327; 108.294381', 'Tình trạng': 'phế tích', 'Phân loại': 'Di tích khảo cổ', 'Ngày công nhận': '22 tháng 12, 2016', 'Quyết định': '2499/QĐ-TTg[1]'}
# {'page': 'Tháp Bằng An', 'Thờ': 'Shiva', 'Xây dựng': 'thế kỷ 12', 'Vị trí': 'Quảng Nam,\xa0 Việt Nam'}
# {'page': 'Tháp Chiên Đàn', 'Phong cách': 'Mỹ Sơn A1', 'Xây dựng': 'thế kỷ 11', 'Vị trí': 'Quảng Nam,\xa0 Việt Nam'}
# {'page': 'Tháp Khương Mỹ', 'Phong cách': 'Mỹ Sơn A1', 'Vị trí': 'Quảng Nam,\xa0 Việt Nam'}
# {'page': 'Trà Kiệu'}
# {'page': 'Bia mộ Nguyễn Trường Tộ'}
# {'page': 'Đền Cờn', 'Địa chỉ': 'phường Quỳnh Phương, thị xã Hoàng Mai, tỉnh Nghệ An,\xa0Việt Nam', 'Phân loại': 'Di tích lịch sử – văn hóa', 'Ngày công nhận': '1993', 'Quyết định': '68/QĐ-BVHTT'}
# {'page': 'Đền Khai Long'}
# {'page': 'Kênh Nhà Lê'}
# {'page': 'Khu di tích lịch sử Kim Liên', 'Phân cấp': 'Di tích quốc gia đặc biệt', 'Vị trí': 'Nghệ An', 'Công nhận': '1956', 'Website': 'Trang web chính thức', 'Tọa độ': '18°40′47,5″B 105°33′7,2″Đ\ufeff / \ufeff18,66667°B 105,55°Đ\ufeff / 18.66667; 105.55000'}
# {'page': 'Làng Vạc'}
# {'page': 'Nhà lưu niệm Nguyễn Tiềm', 'Quốc gia': 'Việt Nam', 'Tỉnh': 'Nghệ An'}
# {'page': 'Quần thể di tích Cố đô Hoa Lư'}
# {'page': 'Cầu ngói Phát Diệm'}
# {'page': 'Chiến khu Quỳnh Lưu'}
# {'page': 'Chùa Dầu'}
# {'page': 'Chùa Non Nước (Ninh Bình)', 'Quốc gia': 'Việt Nam', 'Địa chỉ': 'Thanh Bình, TP Ninh Bình, Ninh Bình', 'Tôn giáo': 'Phật giáo', 'Khởi lập': 'Thời Lý Nhân Tông', 'Người sáng lập': 'Lý Quốc Sư', 'Thầy': 'Thích Thanh Nhiễu', 'Quản lý': 'Giáo hội Phật giáo Việt Nam'}
# {'page': 'Cửa biển Thần Phù'}
# {'page': 'Di tích ở Ninh Bình'}
# {'page': 'Hành cung Vũ Lâm'}
# {'page': 'Đàn Kính Thiên Tràng An'}
# {'page': 'Đền Đông Hội'}
# {'page': 'Đền Kiến Ốc', 'Địa chỉ': 'thôn 8, xã Khánh Trung, huyện Yên Khánh, tỉnh Ninh Bình,\xa0Việt Nam', 'Lễ hội': '2 tháng 2 và 15 tháng 9 âm lịch hàng năm', 'Phân loại': 'Di tích kiến trúc nghệ thuật', 'Ngày công nhận': '13 tháng 2, 1996', 'Quyết định': '310 QĐ/BT[1]'}
# {'page': 'Đền Quảng Phúc'}
# {'page': 'Đền Thánh Nguyễn'}
# {'page': 'Đền thờ Vua Đinh Tiên Hoàng'}
# {'page': 'Đền thờ Vua Lê Đại Hành', 'Công tích': 'đánh tan quân Tống, lập nhà Tiền Lê', 'Thờ': 'tôn thất Tiền Lê', 'Địa chỉ': 'tỉnh Ninh Bình,\xa0Việt Nam', 'Tọa độ': '20°17′10″B 105°54′20″Đ\ufeff / \ufeff20,2862001°B 105,9056228°Đ\ufeff / 20.2862001; 105.9056228', 'Phân loại': 'Di tích lịch sử – văn hóa', 'Ngày công nhận': '28 tháng 4 năm 1962', 'Một phần của': 'Cố đô Hoa Lư[1]', 'Quyết định': '313-VH/VP[2]'}
# {'page': 'Đền Vân Thị'}
# {'page': 'Đền Vực Vông'}
# {'page': 'Động Hoa Lư'}
# {'page': 'Động Thiên Tôn', 'Vị trí': 'Chân núi Voi, thị trấn Thiên Tôn, huyện Hoa Lư, tỉnh Ninh Bình, Việt Nam', 'Tọa độ': '20°17′57″B 105°56′34″Đ\ufeff / \ufeff20,299167°B 105,942778°Đ\ufeff / 20.299167; 105.942778', 'Khám phá': '1981'}
# {'page': 'Gián Khẩu'}
# {'page': 'Hoa Lư'}
# {'page': 'Hoa Lư tứ trấn'}
# {'page': 'Nhà thờ chính tòa Phát Diệm'}
# {'page': 'Nhà thờ họ Đào (Ninh Bình)'}
# {'page': 'Nhà thờ họ Trương Việt Nam'}
# {'page': 'Núi Non Nước'}
# {'page': 'Phòng tuyến Tam Điệp'}
# {'page': 'Phủ Đồi Ngang'}
# {'page': 'Quần thể di tích thờ Vua Đinh ở Ninh Bình'}
# {'page': 'Tam Cốc – Bích Động'}
# {'page': 'Đình Ba Dân', 'Công tích': 'Khai quốc công thần nhà Đinh', 'Địa chỉ': 'xã Tứ Hiệp, huyện Thanh Trì, Hà Nội,\xa0Việt Nam', 'Lễ hội': '14-16 tháng 2 Âm lịch'}
# {'page': 'Đình Bát Tràng', 'Công tích': 'khai quốc công thần nhà Đinh', 'Thánh tích': 'thành hoàng Thăng Long', 'Địa chỉ': 'làng Bát Tràng, xã Bát Tràng, huyện Gia Lâm, thành phố Hà Nội,\xa0Việt Nam', 'Thành lập': '1720'}
# {'page': 'Đình Chèm', 'Địa chỉ': 'phường Thụy Phương, quận Bắc Từ Liêm, Hà Nội,\xa0Việt Nam', 'Lễ hội': '14 - 16 tháng 5 ÂL', 'Phân loại': 'Di tích kiến trúc nghệ thuật', 'Ngày công nhận': '25/12/2017', 'Quyết định': '2082/QĐ-TTg'}
# {'page': 'Đình Chu Quyến', 'Thờ': 'nhân vật lịch sử', 'Địa chỉ': 'Việt Nam', 'Tọa độ': '21°11′46″B 105°26′34″Đ\ufeff / \ufeff21,196232°B 105,442898°Đ\ufeff / 21.196232; 105.442898', 'Thành lập': 'thế kỷ 17', 'Phân loại': 'Di tích lịch sử – văn hóa', 'Ngày công nhận': '28 tháng 4 năm 1962', 'Quyết định': '313-VH/VP[1]'}
# {'page': 'Cụm di tích Đình – Chùa – Bia Bà La Khê'}
# {'page': 'Đình Đào Nguyên', 'Địa chỉ': 'thôn Đào Nguyên, xã An Thượng, huyện Hoài Đức, thành phố Hà Nội,\xa0Việt Nam', 'Lễ hội': '10 tháng 2 (AL)'}
# {'page': 'Đình Đại Phùng', 'Địa chỉ': 'Xã Đan Phượng, Đan Phượng, Hà Nội,\xa0Việt Nam', 'Tọa độ': '21°05′31″B 105°39′55″Đ\ufeff / \ufeff21,091854686288°B 105,66532768932°Đ\ufeff / 21.091854686288244; 105.66532768932383', 'Thành lập': 'Đầu thế kỷ 17', 'Lễ hội': '18 tháng 1\n12 tháng 2\n18 tháng 11', 'Phân loại': 'Di tích kiến trúc nghệ thuật', 'Ngày công nhận': '31 tháng 12 năm 2019', 'Quyết định': '1954/QĐ-TTg[1]'}
# {'page': 'Đình Giàn', 'Được thờ vì': 'tướng quân của Lý Nam Đế, góp công đánh giặc Lương', 'Địa chỉ': 'Xuân Đỉnh, Bắc Từ Liêm, Hà Nội,\xa0Việt Nam', 'Tọa độ': '21°4′29″B 105°47′11″Đ\ufeff / \ufeff21,07472°B 105,78639°Đ\ufeff / 21.07472; 105.78639', 'Diện tích': '4000m²', 'Lễ hội': '9 tháng 2 ÂL', 'Phân loại': 'Di tích lịch sử – văn hóa', 'Ngày công nhận': '1990'}
# {'page': 'Đình Hạ Hiệp', 'Tên khác': 'Đình Liên HiệpĐình Kẻ Hiệp', 'Địa chỉ': 'Liên Hiệp, Phúc Thọ, Hà Nội,\xa0Việt Nam', 'Tọa độ': '21°03′42″B 105°38′35″Đ\ufeff / \ufeff21,061610539525°B 105,64295180578°Đ\ufeff / 21.061610539525322; 105.64295180578043', 'Thành lập': 'Đầu thế kỷ 17', 'Lễ hội': '13 tháng 2 âm lịch', 'Phân loại': 'Di tích kiến trúc nghệ thuật', 'Ngày công nhận': '31/12/2020', 'Quyết định': '2280/QĐ-TTg'}
# {'page': 'Đình Hoàng Mai'}
# {'page': 'Đền Kim Liên', 'Tên khác': 'Đình Kim Liên, Kim Liên từ, đền Cao Sơn', 'Địa chỉ': '148 phố Kim Hoa, phường Phương Liên, quận Đống Đa, thành phố Hà Nội,\xa0Việt Nam', 'Thành lập': '1509', 'Người sáng lập': 'Lê Tương Dực', 'Lễ hội': '16 tháng 3 âm lịch', 'Phân loại': 'Di tích lịch sử – văn hóa,\xa0kiến trúc nghệ thuật', 'Ngày công nhận': '18 tháng 1 năm 2022', 'Một phần của': 'Thăng Long tứ trấn', 'Quyết định': '93/QĐ-TTg[1]'}
# {'page': 'Đình Mông Phụ', 'Địa chỉ': 'thị xã Sơn Tây, Hà Nội,\xa0Việt Nam', 'Tọa độ': '21°09′30″B 105°28′13″Đ\ufeff / \ufeff21,158403°B 105,4703084°Đ\ufeff / 21.158403; 105.4703084', 'Thành lập': '1533', 'Phân loại': 'Di tích lịch sử – văn hóa', 'Ngày công nhận': '1984'}
# {'page': 'Đình Phú Mỹ', 'Công tích': 'đánh đuổi quân Tô Định', 'Địa chỉ': 'thôn Phú Mỹ, xã Tự Lập, huyện Mê Linh, thành phố Hà Nội,\xa0Việt Nam', 'Thành lập': 'thế kỉ XVII', 'Lễ hội': '9-10 tháng 1 (âm lịch)', 'Phân loại': 'Di tích kiến trúc nghệ thuật', 'Ngày công nhận': '1992'}
# {'page': 'Đình So', 'Địa chỉ': 'làng Sơn Lộ, xã Cộng Hòa, Quốc Oai, Hà Nội,\xa0Việt Nam', 'Phân loại': 'Di tích kiến trúc nghệ thuật', 'Ngày công nhận': '10 tháng 7 năm 1980', 'Quyết định': '92-VHTT/QĐ[2]'}
# {'page': 'Đình Tây Đằng', 'Địa chỉ': 'thị trấn Tây Đằng, huyện Ba Vì, thành phố Hà Nội,\xa0Việt Nam', 'Tọa độ': '21°12′B 105°25′Đ\ufeff / \ufeff21,2°B 105,42°Đ\ufeff / 21.2; 105.42', 'Phân loại': 'Di tích kiến trúc nghệ thuật', 'Ngày công nhận': '09 tháng 12 năm 2013', 'Quyết định': '2383/QĐ-TTg[1]'}
# {'page': 'Đình Tường Phiêu', 'Tên khác': 'Đình Cả', 'Địa chỉ': 'Tích Giang, Phúc Thọ, Hà Nội,\xa0Việt Nam', 'Tọa độ': '21°07′02″B 105°31′00″Đ\ufeff / \ufeff21,117084083752°B 105,51670656733°Đ\ufeff / 21.117084083752115; 105.51670656732557', 'Thành lập': '1435', 'Lễ hội': 'Rằm tháng Giêng', 'Phân loại': 'Di tích kiến trúc nghệ thuật', 'Ngày công nhận': '24/12/2018', 'Quyết định': '1820/QĐ-TTg[1]'}
# {'page': 'Đình Vĩnh Ninh', 'Thờ': 'Anh hùng', 'Địa chỉ': 'thôn Vĩnh Ninh, xã Vĩnh Quỳnh, huyện Thanh Trì, Hà Nội,\xa0Việt Nam', 'Phân loại': 'Di tích lịch sử – văn hóa', 'Ngày công nhận': '10 tháng 7 năm 1980', 'Quyết định': '92-VHTT/QĐ[1]'}
# {'page': 'Đình Yên Sở', 'Tên khác': 'Quán Giá, Đền Quán Giá, Đền Giá, Quán Diễm Xá', 'Được thờ vì': 'Danh tướng của Lý Nam Đế', 'Địa chỉ': 'làng Yên Sở, xã Yên Sở, huyện Hoài Đức, thành phố Hà Nội,\xa0Việt Nam', 'Thành lập': 'thời Lý Thái Tổ', 'Lễ hội': '10 tháng 3 ÂL'}
# {'page': 'Chùa Khải Nam'}
# {'page': 'Chùa Sùng Nghiêm Diên Thánh'}
# {'page': 'Cầu Hiền Lương', 'Quốc gia': 'Việt Nam', 'Vị trí': 'Thôn Hiền Lương, xã Hiền Thành, huyện Vĩnh Linh, tỉnh Quảng Trị', 'Tuyến đường': 'Quốc lộ 1', 'Bắc qua': 'Sông Bến Hải', 'Tọa độ': '17°00′14″B 107°03′5,2″Đ\ufeff / \ufeff17,00389°B 107,05°Đ\ufeff / 17.00389; 107.05000\ufeff (Cầu Hiền Lương)'}
# {'page': 'Chùa Quán Thế Âm'}
# {'page': 'Chùa Pháp Lâm'}
# {'page': 'Chùa Bái Đính', 'Quốc gia': 'Việt Nam', 'Địa chỉ': 'Xã Gia Sinh, huyện Gia Viễn, tỉnh Ninh Bình', 'Tôn giáo': 'Phật giáo', 'Tông phái': 'Bắc Tông', 'Khởi lập': 'Khu Chùa cổ năm 1136Khu Chùa mới năm 2003', 'Người sáng lập': 'Lý Quốc Sư-Nguyễn Minh Không (1065 - 1141)', 'Quản lý': 'Công ty Du lịch Tràng An  Doanh nghiệp xây dựng Xuân Trường (70 năm)', 'Trụ trì': 'Hoà thượng Thích Thanh Nhiễu[1]', 'Trang web': 'http://www.baidinh.com'}
# {'page': 'Chùa Bà Ngô (Ninh Bình)', 'Tên tự': 'Đàm Lư', 'Quốc gia': 'Việt Nam', 'Địa chỉ': 'thôn Hoàng Long, xã Trường Yên, Hoa Lư, Ninh Bình', 'Tôn giáo': 'Phật giáo', 'Khởi lập': '979', 'Người sáng lập': 'Ngô phu nhân(Hoàng Thị Thi)', 'Di tích': 'di tích quốc gia đặc biệt'}
# {'page': 'Chùa Duyên Ninh', 'Quốc gia': 'Việt Nam', 'Địa chỉ': 'Khu di tích cố đô Hoa Lư, huyện Hoa Lư, tỉnh Ninh Bình', 'Tôn giáo': 'Phật giáo', 'Tông phái': 'Phật giáo Đại thừa', 'Khởi lập': 'Thời Nhà ĐinhTrùng tu 2014', 'Người sáng lập': 'Vua Đinh Tiên Hoàng', 'Quản lý': 'Giáo hội Phật giáo Việt Nam', 'Trụ trì': 'Đại đức', 'Trang web': 'http://www.phattuvietnam.net'}
# {'page': 'Chùa Đẩu Long', 'Quốc gia': 'Việt Nam', 'Địa chỉ': 'Phường Tân Thành, thành phố Ninh Bình, tỉnh Ninh Bình', 'Tôn giáo': 'Phật giáo', 'Tông phái': 'Phật giáo Đại thừa', 'Khởi lập': 'Năm 984 (năm Thiên Phúc thứ 5)Dựng lại 1944Trùng tu 1992', 'Người sáng lập': 'Vua Lê Đại Hành', 'Quản lý': 'Giáo hội Phật giáo Việt Nam', 'Trụ trì': 'Trần Thái Tông', 'Trang web': 'http://www.phattuvietnam.net'}
# {'page': 'Chùa Kim Ngân', 'Quốc gia': 'Việt Nam', 'Địa chỉ': 'Khu di tích cố đô Hoa Lư, huyện Hoa Lư, tỉnh Ninh Bình', 'Tôn giáo': 'Phật giáo', 'Tông phái': 'Phật giáo Đại thừa', 'Khởi lập': 'Thời Nhà Tiền LêTrùng tu 2010[1]', 'Người sáng lập': 'Vua Lê Đại Hành', 'Quản lý': 'Giáo hội Phật giáo Việt Nam', 'Trụ trì': 'Đại đức', 'Trang web': 'http://www.phattuvietnam.net'}
# {'page': 'Chùa Nhất Trụ', 'Quốc gia': 'Việt Nam', 'Địa chỉ': 'Khu di tích cố đô Hoa Lư, huyện Hoa Lư, tỉnh Ninh Bình', 'Tôn giáo': 'Phật giáo', 'Tông phái': 'Phật giáo Đại thừa', 'Khởi lập': 'Năm 984 (năm Thiên Phúc thứ 5)Dựng lại 1944Trùng tu 1992', 'Người sáng lập': 'Vua Lê Đại Hành', 'Quản lý': 'Giáo hội Phật giáo Việt Nam', 'Trụ trì': 'Đại đức'}
# {'page': 'Đền thờ Công chúa Phất Kim'}
# {'page': 'Động Am Tiên'}
# {'page': 'Khu du lịch sinh thái Tràng An'}
# {'page': 'Phủ Vườn Thiên'}
# {'page': 'Quần thể danh thắng Tràng An', 'Vị trí': 'Ninh Bình, Việt Nam', 'Tiêu chuẩn': 'Hỗn hợp: (v)(vii)(viii)', 'Tham khảo': '1438bis', 'Công nhận': '2014 (Kỳ họp 38)', 'Mở rộng': '2016', 'Diện tích': '6.226\xa0ha (15.380 mẫu Anh)', 'Vùng đệm': '6.026\xa0ha (14.890 mẫu Anh)', 'Tọa độ': '20°15′24″B 105°53′47″Đ\ufeff / \ufeff20,25667°B 105,89639°Đ\ufeff / 20.25667; 105.89639'}
# {'page': 'Sông Sào Khê'}
# {'page': 'Hang Tám Cô'}
# {'page': 'Khu Túc'}
# {'page': 'Lũy Thầy'}
# {'page': 'Quảng Bình quan'}
# {'page': 'Thành Đồng Hới'}
# {'page': 'Quảng trường Ba Đình'}
# {'page': 'Sân bay Bạch Mai', 'Mã IATA-\n\nMã ICAO-': 'Mã IATA-', 'Mã IATA-': 'Mã ICAO-', 'Kiểu sân bay': 'Quân sự', 'Vị trí': 'Thanh Xuân, Hà Nội', 'Độ cao': '50 ft\xa0ft / 15,24 m\xa0m', 'Tọa độ': '20°59′48″B 105°49′55″Đ\ufeff / \ufeff20,99667°B 105,83194°Đ\ufeff / 20.99667; 105.83194', 'Hướng\n\nChiều dài\n\nBề mặt\n\n\nm\n\nft\n\n\n02\n\n2001\n\n6565\n\nAsphalt': 'Hướng', 'Hướng': 'Chiều dài', 'm': 'ft', '02': '2001'}
# {'page': 'Bến Chương Dương'}
# {'page': 'Chùa Hưng Long', 'Quốc gia': 'Việt Nam', 'Địa chỉ': 'thôn Đông Phù, xã Đông Mỹ, huyện Thanh Trì, thành phố Hà Nội', 'Tôn giáo': 'Phật giáo', 'Khởi lập': '1011', 'Người sáng lập': 'Lý Thái Tổ'}
# {'page': 'Chùa Láng', 'Tên tự': 'Chiêu Thiền tự (昭禪寺)', 'Tên khác': 'Pagode des Dames', 'Quốc gia': 'Việt Nam', 'Địa chỉ': '112 phố Chùa Láng, phường Láng Thượng, quận Đống Đa, Hà Nội', 'Tôn giáo': 'Phật giáo', 'Thờ phụng': 'Từ Đạo Hạnh', 'Khởi lập': 'thời vua Lý Anh Tông', 'Người sáng lập': 'vua Lý Anh Tông', 'Quản lý': 'Giáo hội Phật giáo Việt Nam'}
# {'page': 'Chùa Tảo Sách', 'Quốc gia': 'Việt Nam', 'Địa chỉ': 'số 386, đường Lạc Long Quân, phường Nhật Tân, quận Tây Hồ, Hà Nội', 'Tôn giáo': 'Phật giáo', 'Tông phái': 'Phái Tào Động', 'Quản lý': 'Giáo hội Phật giáo Việt Nam', 'Trụ trì': 'Hoà thượng Thích Nguyên Hạnh'}
# {'page': 'Chùa Tự Khoát', 'Quốc gia': 'Việt Nam', 'Địa chỉ': 'thôn Tự Khoát, xã Ngũ Hiệp, huyện Thanh Trì, Hà Nội', 'Tôn giáo': 'Phật giáo', 'Tông phái': 'Giáo hội Phật giáo Việt Nam', 'Khởi lập': 'thời nhà Lý', 'Quản lý': 'Giáo hội Phật giáo Việt Nam'}
# {'page': 'Cột cờ Hà Nội', 'Phong cách': 'Kiến trúc cổ Việt Nam', 'Quốc gia': 'Việt Nam', 'Thành phố': 'Hà Nội', 'Khởi công': '1805', 'Hoàn thành': '1812'}
# {'page': 'Đá Chông'}
# {'page': 'Đạo quán Linh Tiên', 'Tên khác': 'Chùa Linh Tiên', 'Tôn giáo': 'Đạo giáo, Phật giáo', 'Địa chỉ': 'thôn Cao Xá, xã Đức Thượng, huyện Hoài Đức, thành phố Hà Nội,\xa0Việt Nam', 'Thành lập': 'Nhà Triệu (ban đầu),Nhà Mạc (hiện tại)', 'Người sáng lập': 'Lữ Gia (tương truyền)', 'Phân loại': 'Di tích kiến trúc nghệ thuật', 'Ngày công nhận': '9 tháng 1, 1990', 'Quyết định': '34-VH/QĐ'}
# 12.68%

# %%
this = 'Chùa Láng'
print(this)
testurl = HTMLURL + this
# %lprun -f infobox_dict_thing infobox_dict_thing(testurl)
# %time infobox_dict_thing(url)
# Out:
# Chùa Láng
# Timer unit: 1e-07 s
#
# Total time: 1.23658 s
# File: C:\Users\Legion\AppData\Local\Temp\ipykernel_19984\3470613837.py
# Function: infobox_dict_thing at line 2
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      2                                           def infobox_dict_thing(url):
#      3         1   11364004.0 11364004.0     91.9      response = requests.get(url)
#      4         1       3236.0   3236.0      0.0      html = response.json()['parse']['text']
#      5
#      6                                               # Parse the HTML content using BeautifulSoup
#      7         1     971306.0 971306.0      7.9      soup = BeautifulSoup(html, "html.parser")
#      8
#      9                                               # Find the infobox template and extract its contents
#     10         1        936.0    936.0      0.0      infobox = soup.find("table", {"class": "infobox"})
#     11         1          7.0      7.0      0.0      if not infobox:
#     12                                                   return {}
#     13
#     14         1       2442.0   2442.0      0.0      rows = infobox.find_all("tr")
#     15
#     16                                               # Convert the infobox contents into a Pandas DataFrame
#     17         1          2.0      2.0      0.0      data = {}
#     18        15         40.0      2.7      0.0      for row in rows:
#     19        15      21578.0   1438.5      0.2          cells = row.find_all(["th", "td"])
#     20         9         41.0      4.6      0.0          if len(cells) > 1:
#     21         9        903.0    100.3      0.0              key = cells[0].get_text().strip()
#     22         9       1277.0    141.9      0.0              value = cells[1].get_text().strip()
#     23         9         39.0      4.3      0.0              data[key] = value
#     24
#     25         1          2.0      2.0      0.0      return data
